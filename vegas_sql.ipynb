# %%
# coding: utf-8
import json

import requests
import time
import pandas as pd
import matplotlib.pyplot as plt

PATH = 'D:/All About Learning/Quant/mexc'

# %%
def get_current_timestamp():
    timestamp = int(time.time())
    hour = timestamp // 3600 * 3600 * 1000
    return hour

# %%
host = "https://api.mexc.com"
prefix = "/api/v3"
headers = {'Accept': 'application/json', 'Content-Type': 'application/json'}

def get_candle_sticks(pair: str, after: str = '', before: str = '', interval: str = '8h'):
    url = '/klines'
    query_param = f'symbol={pair}&interval={interval}'
    if after != '':
        query_param += f'&startTime={after}'
    if before != '':
        query_param += f'&endTime={before}'

    r = requests.request('GET', host + prefix + url + "?" + query_param, headers=headers)
    return r.json()

# %%
def get_btc_candles():
    btc_list = get_candle_sticks('BTCUSDT')
    btc = pd.DataFrame(btc_list)
    btc.columns = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'turnover']
    btc.set_index('open_time', inplace=True)
    return btc

# %%
def update_EMA(span, pre, new):
    return new * 2 / (1+span) + pre * (1 - 2/(1+span))

# %%
with open(f'{PATH}/pairs.json', 'r') as f:
    pairs = json.load(f)

# %%
from sqlalchemy import create_engine

# 格式：postgresql://username:password@host:port/database
engine = create_engine('postgresql://postgres:postgres2785@localhost:5432/mexc_vegas')

# %%
import re
tokens = []
for p in pairs:
    match = re.match(r'(.*).{4}', p)
    if not match:
        continue
    tokens.append(match.group(1))

with open(f'{PATH}/tokens.json', 'w') as f:
    json.dump(tokens, f)

# %%
import re

for p in pairs:
    pair = pd.read_csv(f'{PATH}/vBTC/{p}.csv', usecols=['open_time', 'MA12', 'MA144', 'MA169', 'MA576', 'MA676'], index_col='open_time')
    match = re.match(r'(.*).{4}', p)
    if not match:
        continue
    token = match.group(1)
    pair.to_sql(token, engine, if_exists='replace', index=True, index_label='open_time')
    print(f'{token} init finish')
# Out:
# 1MIL init finish
# 3D3D init finish
# 3KM init finish
# AAA init finish
# AAG init finish
# AA init finish
# AAVE init finish
# ABBC init finish
# ABC init finish
# ACE init finish
# ACM init finish
# ACN init finish
# ACQ init finish
# AC init finish
# ACX init finish
# ADA init finish
# ADAX init finish
# ADDCLAS init finish
# ADEX init finish
# ADF init finish
# ADS init finish
# AERGO init finish
# AES init finish
# AEUR init finish
# AE init finish
# AFC init finish
# AGII init finish
# AGI init finish
# AGLD init finish
# AGRO init finish
# AGT init finish
# AI2 init finish
# AIAKITA init finish
# AIA init finish
# AIBB init finish
# AIBUDDY init finish
# AICN init finish
# AICORE init finish
# AICREA init finish
# AIDOGEXLM init finish
# AIDOGEX init finish
# AIEMOJI init finish
# AIEN init finish
# AIEPK init finish
# AIE init finish
# AIGENIUS init finish
# AIMX init finish
# AIN init finish
# AIPAD init finish
# AIPLAY init finish
# AIS init finish
# AISWAP init finish
# AITECH init finish
# AITRAN init finish
# AI init finish
# AKITA init finish
# AKITAX init finish
# ALEPH init finish
# ALEX init finish
# ALF init finish
# ALGB init finish
# ALGO init finish
# ALI init finish
# ALLIN init finish
# ALM init finish
# ALPINE init finish
# ALT0 init finish
# ALT init finish
# ALU init finish
# AMA init finish
# AMB init finish
# AMC init finish
# AMD init finish
# AMEN init finish
# AME init finish
# AMG init finish
# AMO init finish
# AMPL init finish
# AMP init finish
# ANC init finish
# ANKR init finish
# ANML init finish
# ANTC init finish
# ANTS init finish
# ANT init finish
# AOS init finish
# APCG init finish
# APD init finish
# APE init finish
# APN init finish
# APT1 init finish
# APX1 init finish
# APX init finish
# ARBGPT init finish
# ARBS init finish
# ARCH init finish
# ARC init finish
# ARGON init finish
# ARG init finish
# ARIX init finish
# ARK init finish
# ARPA init finish
# ARTI init finish
# AR init finish
# ARV init finish
# ARW init finish
# ASM init finish
# ASS init finish
# ASTO init finish
# ASTRADAO init finish
# ASTRA init finish
# ASTRO init finish
# ASTR init finish
# ASVA init finish
# ATC init finish
# ATEM init finish
# ATID init finish
# ATLAS init finish
# ATNT init finish
# ATOLO init finish
# ATOM init finish
# ATPAY init finish
# ATRI init finish
# AURA init finish
# AURORA init finish
# AUR init finish
# AUTO init finish
# AVA init finish
# AVAX init finish
# AVG init finish
# AVTM init finish
# AWO init finish
# AWT init finish
# AXS init finish
# AX init finish
# AYA init finish
# AZERO init finish
# AZERO init finish
# AZIT init finish
# AZY init finish
# BABYDOGE2 init finish
# BABYDOGE init finish
# BABYGROK1 init finish
# BABYMEME1 init finish
# BABYMEMECOIN init finish
# BABY init finish
# BABYX2 init finish
# BABYX init finish
# BADGER init finish
# BAD init finish
# BAI init finish
# BAJU init finish
# BAL init finish
# BANANAGUN init finish
# BANANA init finish
# BART2 init finish
# BARTSIMPSON init finish
# BAR init finish
# BAT init finish
# BAX init finish
# BBC init finish
# BBDC init finish
# BBF init finish
# BBS init finish
# BCB init finish
# BCH init finish
# BCP init finish
# BCT init finish
# BC init finish
# BDT init finish
# BDX init finish
# BEAI init finish
# BEAM init finish
# BEAMX init finish
# BEAR init finish
# BEEF init finish
# BEFE init finish
# BEND init finish
# BEN init finish
# BERRY init finish
# BETA init finish
# BFC init finish
# BFLY init finish
# BFR init finish
# BFT init finish
# BGB init finish
# BGN init finish
# BGT init finish
# BHD1 init finish
# BHO init finish
# BICO init finish
# BID init finish
# BIDZ init finish
# BIGPANDA init finish
# BIGTIME init finish
# BIN init finish
# BIOFI init finish
# BIRD init finish
# BIST init finish
# BIT1 init finish
# BITBULL init finish
# BITCI init finish
# BITCOIN1 init finish
# BITCOINAI init finish
# BITMAT init finish
# BITS init finish
# BIZA init finish
# BKN init finish
# BLANKV2 init finish
# BLAST init finish
# BLA init finish
# BLOK init finish
# BLP init finish
# BLS init finish
# BLT init finish
# BLUES init finish
# BLY init finish
# BNA init finish
# BNB init finish
# BNB init finish
# BNC init finish
# BNX init finish
# BOARD init finish
# BOB2 init finish
# BOBA init finish
# BOBO init finish
# BOB init finish
# BOGEY init finish
# BONDLYV2 init finish
# BOO init finish
# BORING init finish
# BOSON init finish
# BOTTO init finish
# BPC init finish
# BPRIVA init finish
# BRAD init finish
# BRD init finish
# BRISE init finish
# BRN init finish
# BROCK init finish
# BRS init finish
# BSCPAD init finish
# BSCS init finish
# BSPT init finish
# BST init finish
# BSW init finish
# BTC2 init finish
# BTCBAM init finish
# BTC init finish
# BTCS init finish
# BTC init finish
# BTC init finish
# BTM init finish
# BTT init finish
# BUGAT init finish
# BULL init finish
# BUM init finish
# BUNNY init finish
# BUP init finish
# BURGER init finish
# BUSD init finish
# BVG init finish
# BVT init finish
# BXEN init finish
# BXX init finish
# BYN init finish
# BZZ init finish
# CAGA init finish
# CAI init finish
# CAL init finish
# CAND init finish
# CANDY init finish
# CAN init finish
# CAPO init finish
# CARE init finish
# CASHZ init finish
# CAS init finish
# CATGIRL init finish
# CATHEON init finish
# CAT init finish
# CA init finish
# CAWCEO init finish
# CAW init finish
# CBK init finish
# CBX init finish
# CCD init finish
# CCN init finish
# CCT init finish
# CEJI init finish
# CELR init finish
# CELT init finish
# CEL init finish
# CEL init finish
# CENNZ init finish
# CENX init finish
# CERE init finish
# CEX init finish
# CFH init finish
# CGG init finish
# CGPT init finish
# CGPT init finish
# CGV init finish
# CHAMP init finish
# CHANGE init finish
# CHAX init finish
# CHEERS init finish
# CHE init finish
# CHICA init finish
# CHNG init finish
# CHO init finish
# CHRP init finish
# CIRI init finish
# CIRUS init finish
# CITY init finish
# CKB init finish
# CLFI init finish
# CLOAK init finish
# CLORE init finish
# CLOUD init finish
# CLS init finish
# CLUB init finish
# CLV init finish
# CLY init finish
# CMP init finish
# CNC init finish
# CNG init finish
# CNS init finish
# CNTM init finish
# CODAI init finish
# COF init finish
# COGE init finish
# COGO init finish
# COLT init finish
# COMBO init finish
# CONV init finish
# CONX init finish
# COREUM init finish
# COTI init finish
# COVN init finish
# CPAY init finish
# CPFC init finish
# CPH init finish
# CPOS init finish
# CQT init finish
# CRAZYPEPE init finish
# CRDC init finish
# CREO init finish
# CREPE init finish
# CRETA init finish
# CRE init finish
# CRF init finish
# CROWN init finish
# CRTS init finish
# CRT init finish
# CR init finish
# CSIX init finish
# CTC init finish
# CTK init finish
# CTN init finish
# CT init finish
# CTXC init finish
# CULT init finish
# CVNT init finish
# CVP init finish
# CVT init finish
# CVTX init finish
# CVX init finish
# CWAR init finish
# CWEB init finish
# CWS init finish
# CYBERAI init finish
# DAG init finish
# DAI init finish
# DAMEX init finish
# DAO init finish
# DAPPT init finish
# DAPPX init finish
# DARC init finish
# DARK init finish
# DAR init finish
# DCK init finish
# DCR init finish
# DC init finish
# DEB init finish
# DECENFI init finish
# DEGEN init finish
# DEGO init finish
# DEL init finish
# DEP init finish
# DERI init finish
# DERPDEX init finish
# DERP init finish
# DEUS init finish
# DEV init finish
# DEXE init finish
# DEXTF init finish
# DFC init finish
# DFI init finish
# DF init finish
# DFYN init finish
# DGC init finish
# DGH init finish
# DIAMOND init finish
# DICE init finish
# DIE init finish
# DIONE init finish
# DIS init finish
# DKA init finish
# DKS init finish
# DLANCE init finish
# DMT init finish
# DNX init finish
# DOD init finish
# DOGA init finish
# DOGE1 init finish
# DOGE2 init finish
# DOGE69 init finish
# DOGECEO init finish
# DOGECOIN2 init finish
# DOGEKING init finish
# DOGELOGY init finish
# DOGE init finish
# DOGEX init finish
# DOGGO init finish
# DOGGY init finish
# DOGSROCK init finish
# DORKL init finish
# DOSE init finish
# DPEX init finish
# DPR init finish
# DPX init finish
# DRAC init finish
# DRF init finish
# DRM init finish
# DSLA init finish
# DTE init finish
# DTR init finish
# DUSK init finish
# DUX init finish
# DVI init finish
# DVRS init finish
# DVT init finish
# DYP init finish
# DZOO init finish
# DZ init finish
# EARN init finish
# EDEN init finish
# EFC init finish
# EGC init finish
# EGRN init finish
# EG init finish
# EJS init finish
# EKTA init finish
# ELF init finish
# ELMO init finish
# ELONMARS init finish
# EL init finish
# EMGS init finish
# EMPIRE init finish
# EMP init finish
# EMR init finish
# EMT init finish
# EMZ init finish
# ENIX init finish
# ENS init finish
# ENS init finish
# ENTC init finish
# EOSC init finish
# EOS init finish
# EPIKO init finish
# EQ init finish
# ETERNAL init finish
# ETE init finish
# ETH2 init finish
# ETHA init finish
# ETH init finish
# ETHF init finish
# ETHPAD init finish
# ETH init finish
# ETL init finish
# ETP init finish
# ETV init finish
# EUL init finish
# EUL init finish
# EURT init finish
# EVER init finish
# EVE init finish
# EVMOS init finish
# EVRY init finish
# EWC init finish
# EXD init finish
# EXFI init finish
# EYES init finish
# F3 init finish
# FACTR init finish
# FAKT init finish
# FANC init finish
# FANCY init finish
# FARA init finish
# FARM init finish
# FAVR init finish
# FCT2 init finish
# FDV init finish
# FEAR init finish
# FEG init finish
# FERRA init finish
# FGPT init finish
# FIBO init finish
# FIDA init finish
# FID init finish
# FIL init finish
# FINA init finish
# FINE init finish
# FINU init finish
# FIO init finish
# FIRO init finish
# FITFI init finish
# FITFI init finish
# FIT init finish
# FLOKICEO init finish
# FLOYX init finish
# FLUX1 init finish
# FLX init finish
# FMC init finish
# FMXEN init finish
# FNCT init finish
# FNCY init finish
# FND init finish
# FNF init finish
# FNY init finish
# FNZ init finish
# FOG init finish
# FOMO init finish
# FONCOIN init finish
# FON init finish
# FOOD init finish
# FORE init finish
# FORTH init finish
# FORT init finish
# FOR init finish
# FO init finish
# FOXAI init finish
# FOXIFY init finish
# FOX init finish
# FPFT init finish
# FRC init finish
# FREEDOM init finish
# FREE init finish
# FRONT init finish
# FRTS init finish
# FSN init finish
# FTM init finish
# FTN init finish
# FTT init finish
# FUND init finish
# FUNFI init finish
# FUN init finish
# FURUCOMBO init finish
# FUSE init finish
# FUTURE init finish
# FWC init finish
# FWW init finish
# FXDX init finish
# FXS init finish
# FX init finish
# FXY init finish
# FYN init finish
# GAC init finish
# GAIA init finish
# GAI init finish
# GAL init finish
# GAL init finish
# GARI init finish
# GAS init finish
# GAYPEPE init finish
# GBC init finish
# GCAKE init finish
# GDC init finish
# GDO init finish
# GEAR init finish
# GEC init finish
# GEL init finish
# GEM init finish
# GENE1 init finish
# GENE init finish
# GERA init finish
# GFAL init finish
# GFLOKI init finish
# GFLY init finish
# GFT init finish
# GF init finish
# GFY init finish
# GHST init finish
# GHUB init finish
# GLEEC init finish
# GLFT init finish
# GLI init finish
# GLQ init finish
# GLW init finish
# GMEE init finish
# GMMT init finish
# GMPD init finish
# GM init finish
# GMX init finish
# GNO init finish
# GN init finish
# GOAL init finish
# GODE init finish
# GODS init finish
# GOLC init finish
# GOLDFINCH init finish
# GOLD init finish
# GORA init finish
# GORILLA init finish
# GOTG init finish
# GPAY init finish
# GQ init finish
# GRAIL init finish
# GREG init finish
# GRE init finish
# GRIMACE init finish
# GROK1 init finish
# GROK2 init finish
# GROKAI init finish
# GROKBSC init finish
# GROKGPT init finish
# GROK init finish
# GROOOOOK init finish
# GSTBSC init finish
# GST init finish
# GSYS init finish
# GTCOIN init finish
# GTC init finish
# GUILD init finish
# GXT init finish
# GX init finish
# GZONE init finish
# HAC init finish
# HAI init finish
# HAKA init finish
# HALLOWEEN init finish
# HAM init finish
# HANDY init finish
# HAO init finish
# HAPI init finish
# HAPPYCAT init finish
# HARRY init finish
# HATI init finish
# HBAR init finish
# HC init finish
# HDN init finish
# HEART init finish
# HEGIC init finish
# HELLO init finish
# HEME init finish
# HERO init finish
# HER init finish
# HGHG init finish
# HIBS init finish
# HIFI init finish
# HIGH init finish
# HI init finish
# HIVE init finish
# HMTT init finish
# HMT init finish
# HNB init finish
# HNK init finish
# HNS init finish
# HOLD init finish
# HOOD init finish
# HOPR init finish
# HOP init finish
# HOP init finish
# HORD init finish
# HOSKY init finish
# HRT init finish
# HSF init finish
# HTE init finish
# HTM init finish
# HTT init finish
# HT init finish
# HUAHUA init finish
# HUSL init finish
# HUS init finish
# HUT init finish
# HXA init finish
# HYCO init finish
# HYDRA init finish
# HYPC init finish
# HYPES init finish
# HYVE init finish
# HZNDEX init finish
# HZN init finish
# IBAT init finish
# IBOX init finish
# ICT init finish
# IDEA init finish
# IDYP init finish
# IGUP init finish
# IMGNAI init finish
# IMPT init finish
# INFRA init finish
# ING init finish
# INSP init finish
# INST init finish
# INSUR init finish
# INS init finish
# INTER init finish
# INTR init finish
# INVI init finish
# INV init finish
# IOEX init finish
# IONX init finish
# IOST init finish
# IOTX init finish
# IQ init finish
# IRENA init finish
# IRIS init finish
# ISK init finish
# ISP init finish
# ITEM init finish
# ITGR init finish
# ITHEUM init finish
# ITSB init finish
# IUS init finish
# IWELL init finish
# IXT init finish
# IZI init finish
# JAB init finish
# JAM init finish
# JARED init finish
# JASMY init finish
# JCO init finish
# JD init finish
# JEN init finish
# JET init finish
# JEWEL init finish
# JGN init finish
# JINKO init finish
# JOB init finish
# JONES init finish
# JOYSTREAM init finish
# JOY init finish
# JPEG init finish
# JPG init finish
# JSM init finish
# JST init finish
# JULD init finish
# JUNO init finish
# JUR init finish
# JUSTICE init finish
# K21 init finish
# KABOSU init finish
# KAF init finish
# KAI init finish
# KAKA init finish
# KARATE init finish
# KAR init finish
# KASTA init finish
# KAS init finish
# KAT init finish
# KBC init finish
# KBD init finish
# KCS init finish
# KDG init finish
# KEKE init finish
# KFI init finish
# KIBA init finish
# KICKS init finish
# KILT init finish
# KINE init finish
# KING init finish
# KIN init finish
# KISHU init finish
# KKC init finish
# KLADY init finish
# KLAY init finish
# KLC init finish
# KLV init finish
# KMA init finish
# KMON init finish
# KNFT init finish
# KOIN init finish
# KOLNET init finish
# KOL init finish
# KOM init finish
# KONO init finish
# KOY init finish
# KP3R init finish
# KPC init finish
# KREST init finish
# KROM init finish
# KSC init finish
# KSM init finish
# KSN init finish
# KTON init finish
# KT init finish
# KUBE init finish
# KUJI init finish
# KUNCI init finish
# KWENTA init finish
# KXA init finish
# KZEN init finish
# LAI init finish
# LAMB init finish
# LAT init finish
# LAVA init finish
# LAVE init finish
# LAZIO init finish
# LBA init finish
# LBC init finish
# LBLOCK init finish
# LBTC init finish
# LDAO init finish
# LEE init finish
# LEMC init finish
# LEMN init finish
# LEOX init finish
# LFG init finish
# LF init finish
# LGBTQ init finish
# LIEFLAT init finish
# LIFE init finish
# LIKE init finish
# LISA init finish
# LITHO init finish
# LITH init finish
# LITT init finish
# LIT init finish
# LIXX init finish
# LMWR init finish
# LNR init finish
# LOFI init finish
# LOOP init finish
# LOPES init finish
# LOST init finish
# LOTT init finish
# LRC init finish
# LSC init finish
# LSD7 init finish
# LTC2 init finish
# LTC init finish
# LUCA init finish
# LUFC init finish
# LUMI init finish
# LUNA init finish
# LUNCH init finish
# LUNC init finish
# LUNR init finish
# L init finish
# LUXURY init finish
# LVL init finish
# LWD init finish
# LYF init finish
# LYUM init finish
# MAF init finish
# MAGICSHOES init finish
# MAG init finish
# MAKA init finish
# MANC init finish
# MAN init finish
# MAP init finish
# MARBLE init finish
# MARO init finish
# MARS4 init finish
# MARSH init finish
# MASS init finish
# MATH init finish
# MATIC init finish
# MAX init finish
# MBD init finish
# MBLK init finish
# MBOX init finish
# MBOXX init finish
# MBP init finish
# MBX init finish
# MCB init finish
# MCC init finish
# MCHC init finish
# MCOIN init finish
# MCONTENT init finish
# MCRT init finish
# MCTP init finish
# MCT init finish
# MCTU init finish
# MDT init finish
# MDX init finish
# MEE init finish
# MEFA init finish
# MEGA init finish
# MEGODS init finish
# MELD init finish
# MELOS init finish
# MEME2 init finish
# MEMEHA init finish
# MEMEME init finish
# MEMES init finish
# MEMETOON init finish
# MEME init finish
# MEMRSATS init finish
# MENGO init finish
# MEO init finish
# MEOW init finish
# MESA init finish
# METABABY init finish
# METAFI init finish
# METAHERO init finish
# METAL init finish
# METAV init finish
# METFI init finish
# METIS init finish
# METO init finish
# MEV init finish
# MFET init finish
# MFT init finish
# MIDDLE init finish
# MILK init finish
# MILLE init finish
# MILO init finish
# MILOWEB3 init finish
# MIM init finish
# MINA init finish
# MINNA init finish
# MINTI init finish
# MIRL init finish
# MIRTOKEN init finish
# MIR init finish
# MITHRIL init finish
# MITX init finish
# MLN init finish
# MLT init finish
# ML init finish
# MMIT init finish
# MMM init finish
# MMO init finish
# MMUI init finish
# MMY init finish
# MNB init finish
# MNR init finish
# MNTL init finish
# MOBRC init finish
# MOBX init finish
# MOCHI init finish
# MODA init finish
# MOMOV2 init finish
# MONIE init finish
# MONKEYS init finish
# MOONEY init finish
# MOONSEER init finish
# MOON init finish
# MOOV init finish
# MOSPACE init finish
# MOVR init finish
# MPT init finish
# MRST init finish
# MSB init finish
# MSHEESHA init finish
# MSTR init finish
# MTC init finish
# MTH init finish
# MTRG init finish
# MTRM init finish
# MTR init finish
# MTRX init finish
# MT init finish
# MTV init finish
# MUBI init finish
# MUDOL2 init finish
# MURATIAI init finish
# MUTE init finish
# MVL init finish
# MVRS init finish
# MVX init finish
# MWCC init finish
# MXEN init finish
# MXT init finish
# MX init finish
# MX init finish
# MYST init finish
# MYTH init finish
# NABOX init finish
# NADA init finish
# NAKA init finish
# NAOS init finish
# NAO init finish
# NAP init finish
# NAV init finish
# NBS init finish
# NBT init finish
# NCA init finish
# NCDT init finish
# NCT init finish
# NCX init finish
# NEAR init finish
# NEBL init finish
# NEMS init finish
# NEO init finish
# NEOX init finish
# NEPT init finish
# NERD init finish
# NERO init finish
# NEST init finish
# NEW init finish
# NEXA init finish
# NEXT init finish
# NFTC init finish
# NFTY init finish
# NGL init finish
# NGT init finish
# NHT init finish
# NIZA init finish
# NKN init finish
# NLINK init finish
# NLS init finish
# NMR init finish
# NNT init finish
# NODL init finish
# NOM init finish
# NOS init finish
# NOVAX init finish
# NPICK init finish
# NPT init finish
# NRK init finish
# NTP init finish
# NTVRK init finish
# NTX init finish
# NULS init finish
# NUM init finish
# NVT init finish
# NWC init finish
# NWT init finish
# NXDT init finish
# NXD init finish
# NXRA init finish
# NXTT init finish
# NYM init finish
# NZERO init finish
# O3 init finish
# OAS init finish
# OBI init finish
# OBROK init finish
# OBT init finish
# OCC init finish
# OCTA init finish
# OCTAVUS init finish
# OCT init finish
# ODDZ init finish
# OGV init finish
# OGY init finish
# OGZ init finish
# OJA init finish
# OKB init finish
# OKT init finish
# OLEA init finish
# OLE init finish
# OMAX init finish
# OMC init finish
# OMG init finish
# OMNI init finish
# OMNOM init finish
# OMN init finish
# ONG init finish
# ONTP init finish
# OOE init finish
# OPAIGLG init finish
# OPAIG init finish
# OPN init finish
# OPOS init finish
# OPP init finish
# OPUL init finish
# OP init finish
# ORARE init finish
# ORDI2 init finish
# ORD init finish
# ORE init finish
# ORN init finish
# ORT init finish
# OSHI init finish
# OTACON init finish
# OVR init finish
# OWNER init finish
# OZONE init finish
# P00LS init finish
# P3D init finish
# PACMAN init finish
# PACOIN init finish
# PAC init finish
# PAINT init finish
# PALM init finish
# PANDAI init finish
# PANDA init finish
# PANDO init finish
# PARAS init finish
# PARMA init finish
# PART init finish
# PASG init finish
# PAWSWAP init finish
# PAW init finish
# PAXG init finish
# PAXG init finish
# PAYU init finish
# PAZ init finish
# PBR init finish
# PBX init finish
# PC init finish
# PCX init finish
# PEEL init finish
# PEL init finish
# PENDULUM init finish
# PEOPLE init finish
# PEPA init finish
# PEPE2 init finish
# PEPE3 init finish
# PEPEAI init finish
# PEPEBEAST init finish
# PEPECOMMUNITY init finish
# PEPEDAO2 init finish
# PEPEGOD init finish
# PEPERA init finish
# PEPES init finish
# PEPEYE init finish
# PERC init finish
# PERRY init finish
# PET init finish
# PG init finish
# PHAROS init finish
# PHA init finish
# PHB init finish
# PHL init finish
# PIAS init finish
# PIB init finish
# PIG init finish
# PIP init finish
# PIT init finish
# PIVN init finish
# PKN init finish
# PKR init finish
# PLANETS init finish
# PLANET init finish
# PLA init finish
# PLAY init finish
# PLAZ init finish
# PLB init finish
# PLCUC init finish
# PLCU init finish
# PLUG init finish
# PMG init finish
# PMPY init finish
# PNG init finish
# PNK init finish
# POKEMON2 init finish
# POKEMON init finish
# POKT init finish
# POLC init finish
# POLIS init finish
# POLS init finish
# POL init finish
# POLYDOGE init finish
# POND init finish
# POOH init finish
# POOLX init finish
# POPK init finish
# PORTUMA init finish
# POR init finish
# POW init finish
# PPIZZA init finish
# PPT init finish
# PRIMAL init finish
# PRMX init finish
# PRNT init finish
# PROPC init finish
# PROPS init finish
# PROS init finish
# PRQ init finish
# PRTG init finish
# PSG init finish
# PSI init finish
# PSL init finish
# PSP init finish
# PSTAKE init finish
# PSUB init finish
# PSYOP init finish
# PTP init finish
# PUFFIN init finish
# PUMBAA init finish
# PUMPIT init finish
# PUMPKIN init finish
# PUMP init finish
# PUSH init finish
# PXT init finish
# PYM init finish
# PYTH init finish
# QI init finish
# QRDO init finish
# QRL init finish
# QTE init finish
# QTX init finish
# QTZ init finish
# QUACK init finish
# QUICK init finish
# QUINT init finish
# QVI init finish
# RAB init finish
# RACEZOO init finish
# RADAR init finish
# RAFT init finish
# RAK init finish
# RAM init finish
# RANKER init finish
# RARE init finish
# RARI init finish
# RATS2 init finish
# RAT init finish
# RAY init finish
# RAY init finish
# RAZOR init finish
# RBC init finish
# RBN init finish
# RBX1 init finish
# RBX init finish
# RCM init finish
# RDNT init finish
# REAL init finish
# REAP init finish
# REBUS init finish
# RED init finish
# REEF init finish
# REF init finish
# REI init finish
# REL init finish
# RENQ init finish
# REN init finish
# RETS init finish
# RET init finish
# REUNI init finish
# REVO init finish
# REVV init finish
# RFD init finish
# RFOX init finish
# RIBBIT init finish
# RICE init finish
# RIDE init finish
# RIF init finish
# RILLA init finish
# RING init finish
# RIO init finish
# RISE init finish
# RJV init finish
# RLC init finish
# RLY init finish
# RNDX init finish
# ROACHCOIN init finish
# ROCKI init finish
# ROG init finish
# RON init finish
# ROSX init finish
# ROUTE init finish
# RPG init finish
# RPK init finish
# RPL init finish
# RSR init finish
# RSS3 init finish
# RSY init finish
# RUN5KM init finish
# RUNE init finish
# RUSH init finish
# RVF init finish
# RVLT init finish
# SAFEMARS1 init finish
# SAFEREUM init finish
# SAFE init finish
# SAITAMA init finish
# SAI init finish
# SAKAI init finish
# SALD init finish
# SAMA init finish
# SANTOS init finish
# SAT init finish
# SAUBER init finish
# SAUCE init finish
# SBCC init finish
# SBG init finish
# SBR init finish
# SCCP init finish
# SCLP init finish
# SCOTTY init finish
# SCRT init finish
# SCT init finish
# SC init finish
# SDAO init finish
# SDEX init finish
# SDN init finish
# SDP init finish
# SDT init finish
# SD init finish
# SEILOR init finish
# SELF init finish
# SELO init finish
# SEND init finish
# SENSO init finish
# SERO init finish
# SERP init finish
# SER init finish
# SEX init finish
# SEXY init finish
# SFIN init finish
# SFL init finish
# SFM init finish
# SFTY init finish
# SFUND init finish
# SGB init finish
# SGT init finish
# SG init finish
# SHIA init finish
# SHIB2 init finish
# SHIBA2 init finish
# SHIBA init finish
# SHIB init finish
# SHILL init finish
# SHIRYO init finish
# SHIT init finish
# SHIT init finish
# SHOOTER init finish
# SILVER init finish
# SIMPSON1 init finish
# SIMPSON2 init finish
# SIMPSON3 init finish
# SIMPSON4 init finish
# SIMPSON6900 init finish
# SIMPSON init finish
# SIMP init finish
# SIN init finish
# SIX init finish
# SKILL init finish
# SKL init finish
# SKP init finish
# SKY init finish
# SLG init finish
# SLIM init finish
# SLP init finish
# SLT init finish
# SMARS init finish
# SMART init finish
# SMILE init finish
# SML init finish
# SMT init finish
# SMURFCAT init finish
# SNEK init finish
# SNFT init finish
# SOBER init finish
# SODO init finish
# SOFI init finish
# SOIL init finish
# SOLANA2 init finish
# SOLARX init finish
# SOLO init finish
# SOLS init finish
# SOL init finish
# SOLX init finish
# SONIC1 init finish
# SONIC init finish
# SONNE init finish
# SON init finish
# SOON init finish
# SOPH init finish
# SOS init finish
# SOULS init finish
# SOUL init finish
# SOV init finish
# SPACE init finish
# SPAI init finish
# SPARTA init finish
# SPC init finish
# SPFC init finish
# SPGBB init finish
# SPH init finish
# SPIRIT init finish
# SPIZ init finish
# SPONGE init finish
# SPRT init finish
# SPS init finish
# SPT init finish
# SPUME init finish
# SQUID2 init finish
# SRC init finish
# SRDS init finish
# SRLTY init finish
# SRM init finish
# SRT1 init finish
# SRT init finish
# SSV init finish
# SSWP init finish
# STARL init finish
# STARS init finish
# STARWARS init finish
# STAT init finish
# STA init finish
# STEEM init finish
# STEPN init finish
# STETH init finish
# STL init finish
# STND init finish
# STOS init finish
# STPT init finish
# STRIP init finish
# STRK init finish
# STRM init finish
# SUC init finish
# SUDO init finish
# SUIP init finish
# SUI init finish
# SUKU init finish
# SUNDAE init finish
# SUN init finish
# SUP init finish
# SUZUME init finish
# SWAP init finish
# SWASH init finish
# SWEAT init finish
# SWINGBY init finish
# SWI init finish
# SWO init finish
# SWP init finish
# SWRV init finish
# SWTH init finish
# SXM init finish
# SXP init finish
# SYNC init finish
# SYN init finish
# SYP init finish
# SYS init finish
# TAMA init finish
# TANK init finish
# TAO init finish
# TARAL init finish
# TARA init finish
# TCGC init finish
# TEA init finish
# TENET init finish
# TET init finish
# TFBX init finish
# TGT init finish
# THALES init finish
# THG init finish
# THN init finish
# THOL init finish
# TIDAL init finish
# TIE init finish
# TIGER init finish
# TIME init finish
# TIM init finish
# TIN init finish
# TIP init finish
# TITAN init finish
# TKO init finish
# TLOS init finish
# TMNG init finish
# TOKEN init finish
# TOKE init finish
# TOKKI init finish
# TOMI init finish
# TOMS init finish
# TORN init finish
# TOX init finish
# TPT init finish
# TPY init finish
# TRADE init finish
# TRANS init finish
# TRAVA init finish
# TRCL init finish
# TRC init finish
# TREEB init finish
# TRG init finish
# TRIAS init finish
# TRIBE init finish
# TRIVIA init finish
# TRK init finish
# TRL init finish
# TROLL init finish
# TROSS init finish
# TROVE init finish
# TRU1 init finish
# TRUMP2024 init finish
# TRUSTFI init finish
# TRVL init finish
# TRX init finish
# TSN init finish
# TSUGT init finish
# TSUKA init finish
# TSY init finish
# TTC init finish
# TTM init finish
# TTT init finish
# TURT init finish
# TUSD init finish
# TXA init finish
# TYPE init finish
# UBSN init finish
# UBXS init finish
# UBX init finish
# UCF init finish
# UFO init finish
# UFT init finish
# UGAS init finish
# ULTIMA init finish
# ULX init finish
# UMA init finish
# UMB init finish
# UMEE init finish
# UNB init finish
# UNIBOT init finish
# UNI init finish
# UNLEASH init finish
# UNM init finish
# UNO init finish
# UPC init finish
# UPI init finish
# UPO init finish
# USDC init finish
# USDD init finish
# USDD init finish
# USDJ init finish
# USDN init finish
# USDP init finish
# USH init finish
# U init finish
# VAI init finish
# VCF init finish
# VCORE init finish
# VCT init finish
# VC init finish
# VEIL init finish
# VELODROME init finish
# VEMP init finish
# VEXT init finish
# VEX init finish
# VICS init finish
# VIC init finish
# VINU init finish
# VISION init finish
# VIX init finish
# VIZ init finish
# VKT init finish
# VLK init finish
# VMPX init finish
# VMS init finish
# VNN init finish
# VOLTAGE init finish
# VOLT init finish
# VOW init finish
# VRD init finish
# VRS2 init finish
# VRS init finish
# VRSW init finish
# VRTX init finish
# VSC init finish
# VSYS init finish
# VTS init finish
# VV init finish
# W3F init finish
# W3S init finish
# WACME init finish
# WAIT init finish
# WALV init finish
# WASB init finish
# WAS init finish
# WATT init finish
# WAVES init finish
# WAXL init finish
# WAXP init finish
# WBT init finish
# WEFIN init finish
# WEMIX init finish
# WFAI init finish
# WFCA init finish
# WFT init finish
# WHALE init finish
# WILD init finish
# WIN init finish
# WISTA init finish
# WITCH init finish
# WIT init finish
# WMINIMA init finish
# WMI init finish
# WMOXY init finish
# WMT init finish
# WNCG init finish
# WNK init finish
# WNT init finish
# WNXM init finish
# WNZ init finish
# WOFO1 init finish
# WOID init finish
# WOM init finish
# WOOF init finish
# WORK init finish
# WORLDAI init finish
# WPAY init finish
# WRLD init finish
# WSB1 init finish
# WSG init finish
# WSI init finish
# WSM init finish
# WTR init finish
# WWY init finish
# X1 init finish
# X2 init finish
# X2Y2 init finish
# XAI1 init finish
# XAI init finish
# XAUT init finish
# XAVA init finish
# XBOT init finish
# XCAD init finish
# XCN init finish
# XCOIN init finish
# XCOM init finish
# XCORP init finish
# XCV init finish
# XDAG init finish
# XDAO init finish
# XDATA init finish
# XDB init finish
# XDOGE init finish
# XELS init finish
# XEND init finish
# XEN init finish
# XEP init finish
# XETA init finish
# XET init finish
# XFI init finish
# XIDO init finish
# XINU init finish
# XI init finish
# XLS init finish
# XMX init finish
# XNA init finish
# XODEX init finish
# XPB init finish
# XPLA init finish
# XPNET init finish
# XPR init finish
# XPX init finish
# XRAI init finish
# XRD init finish
# XRP2 init finish
# XRP8 init finish
# XRPAYNET init finish
# XRPC init finish
# XRPH init finish
# XRP init finish
# XSHIB init finish
# XSPECTAR init finish
# XTM init finish
# XTOKEN init finish
# XTS init finish
# XUI init finish
# X init finish
# XWG init finish
# XWG init finish
# XX init finish
# XYM init finish
# YACHT init finish
# YAMA init finish
# YAY init finish
# YDF init finish
# YFII init finish
# YFI init finish
# YFX init finish
# YLDY init finish
# YOOSHI init finish
# YURI init finish
# ZAM init finish
# ZAX init finish
# ZBC init finish
# ZBU init finish
# ZCX init finish
# ZEE init finish
# ZELIX init finish
# ZENI init finish
# ZEN init finish
# ZEPH init finish
# ZETRIX init finish
# ZIG init finish
# ZIX init finish
# ZKID init finish
# ZKPEPE init finish
# ZKP init finish
# ZKS init finish
# ZOA init finish
# ZOON init finish
# ZPAY init finish
# ZPC init finish
# ZRX init finish
# ZTX init finish
# ZURR init finish
# ZYB init finish
# ZZZ init finish

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="mexc_vegas",
    user="postgres",
    password="postgres2785",
    host="localhost",
    port="5432"
)

# %%
btc_df = get_btc_candles()

token = 'ALGO'
# 数据库连接参数
conn_params = {
    'dbname': 'mexc_vegas',
    'user': 'postgres',
    'password': 'postgres2785',
    'host': 'localhost',
    'port': '5432'
}

# 连接到数据库
conn = psycopg2.connect(**conn_params)

# 创建一个 cursor 对象用来执行 SQL 查询
cur = conn.cursor()

# 编写 SQL 查询，获取 open_time 最大的行
query = f'SELECT * FROM "{token}" ORDER BY open_time DESC LIMIT 1;'

try:
    # 执行 SQL 查询
    cur.execute(query)

    # 获取查询结果
    row = cur.fetchone()
    if not row:
        print("No rows found.")
        exit(0)
    print(row)
    start_time, MA12, MA144, MA169, MA576, MA676 = row
    now = get_current_timestamp()
    if start_time+8*60*60*1000 < now:
        exit(0)
    new_data = get_candle_sticks(f'{token}USDT', after=start_time, before=now)
    try:
        for open_time, open_price, *_ in new_data:
            open_price = float(open_price)
            btc_price = float(btc_df.loc[open_time]['open'])
            vbtc = open_price/btc_price
            MA12 = update_EMA(12, MA12, vbtc)
            MA144 = update_EMA(144, MA144, vbtc)
            MA169 = update_EMA(169, MA169, vbtc)
            MA576 = update_EMA(576, MA576, vbtc)
            MA676 = update_EMA(676, MA676, vbtc)

            cur.execute(f'INSERT INTO "{token}" (open_time, "MA12", "MA144", "MA169", "MA576", "MA676") VALUES ({open_time}, {MA12}, {MA144}, {MA169}, {MA576}, {MA676});')
        conn.commit()
        cur.close()
        # 可能没更新
    except KeyError as e:
        print(f"btc price not exist")

except psycopg2.Error as e:
    # 打印数据库错误信息
    print("Database error:", e)
finally:
    # 关闭 cursor 和连接
    cur.close()
    conn.close()
# Out:
# (1702886400000, 4.669136359963135e-06, 3.943797025312407e-06, 3.893577029278243e-06, 4.40880144979345e-06, 4.710453946690819e-06)

# %%
get_current_timestamp()
# Out:
# 1702908000000
